# %% [markdown]
# <img src="Diagrama Nequi.png" alt="Getting started" />

# %%
class Nequi:
    dinero=0
    cuanta_ahorro=0
    def meter(self):
        dinero_meter=int(input('ingrese la cantidad de dinero a guardar'))
        self.dinero=self.dinero+dinero_meter
        print(f'se ha guardado el dinero, actualmente hay $ {self.dinero} en su cuenta')
    def sacar(self):
        dinero_sacar=int(input('ingrese la cantidad de dinero a sacar'))
        while self.dinero<dinero_sacar:
            print('no puede sacar dinero ya que la cantidad que desea es mayor')
            dinero_sacar=int(input(f'tiene $ {self.dinero}, ingrese la cantidad de dinero a sacar'))
        self.dinero=self.dinero-dinero_sacar
        print(f'el dinero se ha retirado, ahora hay $ {self.dinero} en la cuenta')


class Usuarios(Nequi):
    def __init__(self):
        self.usuario=[]
        self.contraseña=[]
        self.identificacion=[]
        self.nombre=[]
        self.apellido=[]
        self.contraseña_ahorro=[]

    def registrar(self):
        self.usuario.append(str(input('ingrese su numero de telefono, este se utilizará como su usuario')))
        self.contraseña.append(str(input('ingrese una contraseña para su cuenta')))
        self.identificacion.append(str(input('ingrese su identificacion')))
        self.nombre.append(str(input('ingrese su nombre')))
        self.apellido.append(str(input('ingrese su apellido')))
        print('usuario registrado')
        print('\tUsuario:',self.usuario)
        print('\tnombre:',self.nombre,self.apellido,'\n')

    def mostrar_usuario(self):
        return self.usuario
        
    def verificar_contraseña(self):
        while True:
            contraseñaaverificar=[]
            contraseñaaverificar.append(str(input('digite su contraseña')))
            if contraseñaaverificar==self.contraseña:
                break
        print('contraseña:',contraseñaaverificar)

    def crea_ca (self):
        self.contraseña_ahorro.append(str(input('se utilizaran los datos de la cuenta actual para crear la cuenta de ahorro, a continuacion cree una contraseña para la cuenta de ahorro')))
        print(f'cuenta de ahorro creada\n\tUsuario: {self.usuario} \n\tContraseña: {self.contraseña_ahorro}')
        while True:
            salir_ca=int(input('presione (1) para vover a la cuenta principal'))
            if salir_ca==1:
                break

    

class Ingresar(Usuarios):
    def entrar(self):
        if opcion_usuario==1:
            print('Usuario:',usuario1.mostrar_usuario())
            usuario1.verificar_contraseña()
            while True:
                while True:
                    opcion_realizar=int(input('elija la opcion. (1)guardar dinero (2)sacar dinero (3)crear cuenta de ahorro (4)cerrar seccion'))
                    if opcion_realizar>0 and opcion_realizar<5:
                        break
                if opcion_realizar==1:
                    usuario1.meter()
                elif opcion_realizar==2:
                    usuario1.sacar()
                elif opcion_realizar==3:
                    usuario1.crea_ca()
                    print('está de nuevo en la cuenta principal')
                elif opcion_realizar==4:
                    print('seccion cerrada\n')
                    break
            
        else:
            print('Usuario:',usuario2.mostrar_usuario()) 
            usuario2.verificar_contraseña()
            while True:
                while True:
                    opcion_realizar=int(input('elija la opcion. (1)guardar dinero (2)sacar dinero (3)crear cuenta de ahorro (4)cerrar seccion'))
                    if opcion_realizar>0 and opcion_realizar<5:
                        break
                if opcion_realizar==1:
                    usuario2.meter()
                elif opcion_realizar==2:
                    usuario2.sacar()
                elif opcion_realizar==3:
                    usuario2.crea_ca()
                    print('está de nuevo en la cuenta principal')
                elif opcion_realizar==4:
                    print('seccion cerrada\n')
                    break

usuario1=Ingresar()
usuario2=Ingresar()
print('usuario 1')
usuario1.registrar()
print('usuario 2')
usuario2.registrar()

print('Bienvenido a Nequi')
while True:
    while True:
        opcion_usuario=int(input('con cual usuario desea ingresar? (1 o 2),puede presionar (0) para salir de "Nequi"'))
        if opcion_usuario<3:
            break
    if opcion_usuario==1:
        usuario1.entrar()
    elif opcion_usuario==2:
        usuario2.entrar()
    if opcion_usuario==0:
        print('"Nequi" se ha cerrado')
        break
# Out:
# usuario 1
# usuario registrado
# 	Usuario: ['3176191179']
# 	nombre: ['Daniel'] ['Villaneda']
#
# usuario 2
# usuario registrado
# 	Usuario: ['3045568467']
# 	nombre: ['Jose22'] ['torres']
#
# Bienvenido a Nequi
# Usuario: ['3176191179']
# contraseña: ['Daniel22']
# se ha guardado el dinero, actualmente hay $ 50000 en su cuenta
# el dinero se ha retirado, ahora hay $ 46000 en la cuenta
# seccion cerrada
