# %% [markdown]
# 1)    Construya la clase Usuario y solicita la información básica de los usuario de una Biblioteca
#
# 2)    Crea una clase Libro que modele la información que se mantiene en una biblioteca sobre cada libro: título, autor (usa la clase Persona), ISBN, páginas, edición, editorial , lugar (ciudad y país) y fecha de edición (usa la clase Fecha). La clase debe proporcionar los siguientes servicios: accedentes y mutadores, (get y set) método para leer la información y método para mostrar la información. Este último método mostrará la información del libro con este formato:
#
#
#     Título: Introduction to Java Programming
#
#     3a. edición
#
#     Autor: Liang, Y. Daniel
#
#     ISBN: 0-13-031997-X
#
#     Prentice-Hall, New Jersey (USA), viernes 16 de noviembre de 2001
#
#     784 páginas
#
#
# 3)    Aprovechando lo anterior construya una clase que me permita prestar un libro

# %%
import datetime
libros=[]
usuarios=[]
class Persona:
    def __init__(self):
        self.nombre=""
        self.apellido=""
        self.identificacion=""
    
    def set_nombre(self,nombre):
        self.nombre=nombre
    
    def get_nombre(self):
        return self.nombre

    def set_apellido(self,apellido):
        self.apellido=apellido
    
    def get_apellido(self):
        return self.apellido

    def set_identificacion(self,identificacion):
        self.identificacion=identificacion
    
    def get_identificacion(self):
        return self.identificacion
    
    def mostrar_persona(self):
        print('\tNombre:',self.nombre,self.apellido)
        print('\tIdentificación:',self.identificacion)
        
class Fecha:
    def __init__(self):
        self.fecha=""

    def set_fecha(self,fecha):
        self.fecha=fecha
    
    def get_fecha(self):
        return self.fecha
    
    def fecha_actual(self):
        self.fecha_hora=datetime.date.today()

    def get_fecha_actual(self):
        return self.fecha_hora

class Usuario(Persona):
    def __init__(self):
        self.direccion=""
        self.telefono=""

    def set_direccion(self,direccion):
        self.direccion=direccion
    
    def get_direccion(self):
        return self.direccion

    def set_telefono(self,telefono):
        self.telefono=telefono
    
    def get_telefono(self):
        return self.telefono

    def agregar_usuario(self):
        if cantidad_usuarios==0:
            usuario1.set_nombre(str(input('ingrese el nombre')))
            usuario1.set_apellido(str(input('ingrese el apellido')))
            usuario1.set_identificacion(str(input('ingrese la identificación')))
            usuario1.set_direccion(str(input('ingrese la direccion')))
            usuario1.set_telefono(str(input('ingrese el telefono')))
            nombre_completo=self.nombre+self.apellido
            usuarios.append(nombre_completo)
            print(usuarios)
        elif cantidad_usuarios==1:
            usuario2.set_nombre(str(input('ingrese el nombre')))
            usuario2.set_apellido(str(input('ingrese el apellido')))
            usuario2.set_identificacion(str(input('ingrese la identificación')))
            usuario2.set_direccion(str(input('ingrese la direccion')))
            usuario2.set_telefono(str(input('ingrese el telefono')))
            nombre_completo=self.nombre+self.apellido
            usuarios.append(nombre_completo)
            print(usuarios)

    def mostrar_usuario(self):
        print('\tNombre:',self.nombre,self.apellido)
        print('\tIdentificación:',self.identificacion)
        print('\tDirección:',self.direccion)
        print('\tTelefono:',self.telefono,'\n')
        

class Libro(Persona and Fecha):
    def __init__(self):
        self.titulo=""
        self.autor=""
        self.isbn=""
        self.paginas=""
        self.edicion=""
        self.editorial=""
        self.lugar=""
        
    def set_titulo(self,titulo):
        self.titulo=titulo
    
    def get_titulo(self):
        return self.titulo
    
    def set_autor(self,autor):
        self.autor=autor
    
    def get_autor(self):
        return self.autor

    def set_isbn(self,isbn):
        self.isbn=isbn
    
    def get_isbm(self):
        return self.isbn

    def set_paginas(self,paginas):
        self.paginas=paginas
    
    def get_paginas(self):
        return self.paginas

    def set_edicion(self,edicion):
        self.edicion=edicion
    
    def get_edicion(self):
        return self.edicion

    def set_editorial(self,editorial):
        self.editorial=editorial
    
    def get_editorial(self):
        return self.editorial

    def set_lugar(self,lugar):
        self.lugar=lugar
    
    def get_lugar(self):
        return self.lugar

    def agregar_libro(self):
        if cantidad_libros==0:
            libro1.set_titulo(str(input('ingrese el titulo del libro')))
            libro1.set_autor(str(input('ingrese el nombre del autor del libro')))
            libro1.set_isbm(str(input('ingrese el ISBM del libro')))
            libro1.set_paginas(str(input('ingrese el numero de paginas del libro')))
            libro1.set_edicion(str(input('ingrese la edición del libro')))
            libro1.set_editorial(str(input('ingrese el editorial del libro')))
            libro1.set_lugar(str(input('ingrese lugar de edición del libro')))
            libro1.set_fecha(str(input('ingrese la fecha de edición del libro')))
            libros.append(self.titulo)

        elif cantidad_libros==1:
            libro2.set_titulo(str(input('ingrese el titulo del libro')))
            libro2.set_autor(str(input('ingrese el nombre del autor del libro')))
            libro2.set_isbm(str(input('ingrese el ISBM del libro')))
            libro2.set_paginas(str(input('ingrese el numero de paginas del libro')))
            libro2.set_edicion(str(input('ingrese la edición del libro')))
            libro2.set_editorial(str(input('ingrese el editorial del libro')))
            libro2.set_lugar(str(input('ingrese lugar de edición del libro')))
            libro2.set_fecha(str(input('ingrese la fecha de edición del libro')))
            libros.append(self.titulo)
        

    def mostrar_libro(self):
        print(f'\tTitulo: {self.get_titulo()}')
        print(f'\tAutor: {self.get_autor()}')
        print(f'\tISBM: {self.get_isbm()}')
        print(f'\tPaginas: {self.get_paginas()}')
        print(f'\tEdición: {self.get_edicion()}')
        print(f'\tEditorial: {self.get_editorial()}')
        print(f'\tLugar: {self.get_lugar()}')
        print(f'\tFecha: {self.get_fecha()} \n')

class Prestar(Usuario,Libro):
    def datos_prestar(self):
        self.set_nombre(str(input('ingrese el nombre de la persona a prestar')))
        self.set_apellido(str(input('ingrese el apellido de la persona a prestar')))
        self.set_identificacion(str(input('ingrese la identificación de la persona a prestar')))
        self.set_direccion(str(input('ingrese la dirección de la persona a prestar')))
        self.set_telefono(str(input('ingrese el telefono de la persona a prestar')))
        self.set_titulo(str(input('ingrese el titulo del libro a prestar')))
        self.fecha_actual()
        libros.remove(self.titulo)

    def mostrar_datos_prestar(self):
        print('Prestar:')
        print(f'\tNombre: {self.get_nombre()} {self.get_apellido()}')
        print(f'\tIdentificación: {self.get_identificacion()}')
        print(f'\tDirección: {self.get_direccion()}')
        print(f'\tTelefono: {self.get_telefono()}')
        print(f'\tLibro: {self.get_titulo()}')
        print(f'\tFecha {self.get_fecha_actual()} \n')


print('BIBLIOTECA CENTRAL','\nBienvenido','\n')
while True:
    while True:
        opcion=int(input('que desea hacer. (1)registrar usuario (2)guardar libro (3)prestar un libro (4)salir'))
        if opcion > 0 and opcion < 5:
            break
    if opcion==1:
        cantidad_usuarios=len(usuarios)
        if cantidad_usuarios==0:
            usuario1=Usuario()
            print('Usuario:')
            usuario1.agregar_usuario()
            usuario1.mostrar_usuario()
        elif cantidad_usuarios==1:
            usuario2=Usuario()
            usuario2.agregar_usuario()
            usuario2.mostrar_usuario()
        elif cantidad_usuarios==2:
            print('no se pueden agregar mas usuarios')
        
    elif opcion==2:
        cantidad_libros=len(libros)
        if cantidad_libros==0:
            libro1=Libro()
            print('Libro:')
            libro1.agregar_libro()
            libro1.mostrar_libro()
        elif cantidad_libros==1:
            libro2=Libro()
            print('Libro:')
            libro2.agregar_libro()
            libro2.mostrar_libro()
        elif cantidad_libros==2:
            print('no se pueden guardar mas libros')

    elif opcion==3:
        cantidad_libros=len(libros)
        if cantidad_libros>0:
            prestar1=Prestar()
            prestar1.datos_prestar()
            prestar1.mostrar_datos_prestar()
        else:
            print('no hay libros para prestar')
    else:
        print('finalizado')
        break
# Out:
# BIBLIOTECA CENTRAL
# Bienvenido
#
# Libro:
# 	Titulo: los plones
# 	Autor: La mirla
# 	ISBM: 1-0382-87
# 	Paginas: 144
# 	Edición: 3 edicion
# 	Editorial: la esquina del pegue
# 	Lugar: la esquina
# 	Fecha: 2022-22-02
#
# Prestar:
# 	Nombre: daniel villaneda
# 	Identificación: 10727372
# 	Dirección: Cra 3
# 	Telefono: 3918282
# 	Libro: los plones
# 	Fecha 2022-11-22
#
# no hay libros para prestar
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [2], line 202
#     200 while True:
#     201     while True:
# --> 202         opcion=int(input('que desea hacer. (1)registrar usuario (2)guardar libro (3)prestar un libro (4)salir'))
#     203         if opcion > 0 and opcion < 5:
#     204             break
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import datetime
class Fecha:
    def __init__(self):
        self.fecha=""
    
    def fecha_actual(self):
        fecha=datetime.date.today()
        print(fecha)

x=Fecha()
x.fecha_actual()
# Out:
# 2022-11-20
